# %%
import matplotlib 
import matplotlib.pyplot as plt
import cv2
import plotly
from matplotlib.widgets import Button

# %matplotlib qt


plt.close() 

file = 'demo.png'
img = cv2.imread(file)


fig, ax = plt.subplots()
ax.imshow(img)
hpoints = ax.plot([], [])
coords = []

ax.set_xlabel('[left click]: add point, [right click]: remove point')


def onclick(event):
    global hpoints
    print(event)
    ix, iy = event.xdata, event.ydata

    if event.inaxes != ax:
        return None

    if (ix ==None) or (iy ==None):
        return None

    if event.button ==1: # left click, add point
        ix = int(ix)
        iy = int(iy)
        print (f'add point: x = {ix}, y = {iy}')
        global coords
        coords.append((ix, iy))

    if event.button ==3 and len(coords)>0: # right click, remove point
        d = [(ix -d[0])**2+(iy -d[1])**2 for d in coords]
        idxmin = d.index(min(d))
        coords.pop(idxmin)  # remove closest point
        print (f'add point: index = {idxmin}')

    # sort points and redraw
    coords.sort(key = lambda x: x[0])
    hpoints.pop(0).remove()
    hpoints = ax.plot([c[0] for c in coords], [c[1] for c in coords],  marker = 'o', markersize = 20, c = 'r', fillstyle = 'none', linestyle = '--')
    print(coords)
    fig.canvas.draw()
    return coords

def confirm(event):
    print('saved')


cid = fig.canvas.mpl_connect('button_press_event', onclick)


ax_confirm = fig.add_axes([0.7, 0.05, 0.1, 0.075])
button_confirm = Button(ax_confirm, 'Previous')
button_confirm.on_clicked(confirm)
# Out:
# 0
# button_press_event: xy=(238, 196) xydata=(546.766129032258, 602.5903225806453) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 546, y = 602
# [(546, 602)]
# button_press_event: xy=(376, 230) xydata=(1024.758064516129, 484.82419354838726) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 1024, y = 484
# [(546, 602), (1024, 484)]
# button_press_event: xy=(433, 260) xydata=(1222.1895161290322, 380.91290322580664) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 1222, y = 380
# [(546, 602), (1024, 484), (1222, 380)]
# button_press_event: xy=(497, 288) xydata=(1443.866935483871, 283.9290322580648) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 1443, y = 283
# [(546, 602), (1024, 484), (1222, 380), (1443, 283)]
# ...
