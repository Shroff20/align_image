# %%
import matplotlib 
import matplotlib.pyplot as plt
import cv2
import plotly

# %matplotlib qt


plt.close() 

file = 'demo.png'

img = cv2.imread(file)


fig, ax = plt.subplots()

ax.imshow(img)
hpoints = ax.plot([], [],  marker = 'o', markersize = 20, c = 'r')


coords = []

def onclick(event):
    global hpoints

    ix, iy = event.xdata, event.ydata

    if (ix ==None) or (iy ==None):
        return None

    if event.button ==1: # left click

        ix = int(ix)
        iy = int(iy)
        print (f'add point: x = {ix}, y = {iy}')
        global coords
        coords.append((ix, iy))


    if event.button ==3: # right click
        
        d = [(ix -d[0])**2+(iy -d[1])**2 for d in coords]

        idxmin = d.index(min(d))
        coords.pop(idxmin)  # remove closest point

        print(d, idxmin)

    coords.sort(key = lambda x: x[0])

    hpoints.pop(0).remove()
    hpoints = ax.plot([c[0] for c in coords], [c[1] for c in coords],  marker = 'o', markersize = 20, c = 'r')

    print(coords)
    fig.canvas.draw()

    return coords


cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# add point: x = 193, y = 748
# [(193, 748)]
# add point: x = 574, y = 647
# [(193, 748), (574, 647)]
# add point: x = 764, y = 519
# [(193, 748), (574, 647), (764, 519)]
# add point: x = 1142, y = 353
# [(193, 748), (574, 647), (764, 519), (1142, 353)]
# add point: x = 1405, y = 259
# [(193, 748), (574, 647), (764, 519), (1142, 353), (1405, 259)]
# [951745.9883480747, 344970.47544484894, 129950.50125130065, 2741.2947996878383, 109922.59802549436] 3
# [(193, 748), (574, 647), (764, 519), (1405, 259)]
# [410929.5102003121, 64403.28761966697, 678.1521357960444, 443457.2811680542] 2
# [(193, 748), (574, 647), (1405, 259)]
# [179703.32483350678, 889.9248335067645, 787567.1280593132] 1
# [(193, 748), (1405, 259)]
# add point: x = 636, y = 432
# [(193, 748), (636, 432), (1405, 259)]
# add point: x = 685, y = 554
# [(193, 748), (636, 432), (685, 554), (1405, 259)]
# add point: x = 1031, y = 401
# [(193, 748), (636, 432), (685, 554), (1031, 401), (1405, 259)]
# add point: x = 1076, y = 211
# [(193, 748), (636, 432), (685, 554), (1031, 401), (1076, 211), (1405, 259)]
# [1284225.390884495, 393955.8618522372, 365906.2424973984, 53726.107013527544, 58317.04249739858, 32617.43604578569] 5
# [(193, 748), (636, 432), (685, 554), (1031, 401), (1076, 211)]
# add point: x = 1457, y = 238
# [(193, 748), (636, 432), (685, 554), (1031, 401), (1076, 211), (1457, 238)]
# add point: x = 1672, y = 145
# [(193, 748), (636, 432), (685, 554), (1031, 401), (1076, 211), (1457, 238), (1672, 145)]
