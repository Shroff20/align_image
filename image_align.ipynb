# %%
import matplotlib 
import matplotlib.pyplot as plt
import cv2
import plotly
from matplotlib.widgets import Button
import pandas as pd

# %matplotlib qt


plt.close() 

file = 'demo.png'
img = cv2.imread(file)


fig, ax = plt.subplots()
ax.imshow(img)
hpoints = ax.plot([], [])
df_xy = pd.DataFrame(columns = ['x', 'y'])

ax.set_xlabel('[left click]: add point, [right click]: remove point')


def onclick(event):
    global hpoints
    global df_xy
    global fig
    global ax

    print(event)
    ix, iy = event.xdata, event.ydata

    if event.inaxes != ax:
        return None

    if (ix ==None) or (iy ==None):
        return None

    if event.button ==1: # left click, add point
        ix = int(ix)
        iy = int(iy)
        print (f'add point: x = {ix}, y = {iy}')
        df_xy = df_xy._append( {'x':ix, 'y':iy} , ignore_index=True)

    if event.button ==3 and len(df_xy)>0: # right click, remove point
        d = (ix-df_xy['x'])**2 + (iy-df_xy['y'])**2
        idx = d.idxmin()
        df_xy = df_xy.drop(idx)
        print (f'remove point: index = {idx}')


    # sort points and redraw
    df_xy=df_xy.sort_values('x').reset_index(drop = True)
    hpoints.pop(0).remove()
    hpoints = ax.plot(df_xy['x'], df_xy['y'],  marker = 'o', markersize = 20, c = 'r', fillstyle = 'none', linestyle = '--')
    print(df_xy)
    fig.canvas.draw()
    return df_xy

def confirm(event):
    print('saved')


cid = fig.canvas.mpl_connect('button_press_event', onclick)


ax_confirm = fig.add_axes([0.7, 0.05, 0.1, 0.075])
button_confirm = Button(ax_confirm, 'Previous')
button_confirm.on_clicked(confirm)
# Out:
# 0
# button_press_event: xy=(156, 161) xydata=(262.7419354838709, 723.8201612903227) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 262, y = 723
#      x    y
# 0  262  723
# button_press_event: xy=(254, 199) xydata=(602.1854838709678, 592.1991935483873) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 602, y = 592
#      x    y
# 0  262  723
# 1  602  592
# button_press_event: xy=(365, 240) xydata=(986.6572580645161, 450.1870967741937) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 986, y = 450
#      x    y
# 0  262  723
# 1  602  592
# 2  986  450
# button_press_event: xy=(266, 195) xydata=(643.75, 606.0540322580647) button=3 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# remove point: index = 1
#      x    y
# 0  262  723
# 1  986  450
# button_press_event: xy=(264, 203) xydata=(636.8225806451612, 578.3443548387098) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 636, y = 578
#      x    y
# 0  262  723
# 1  636  578
# 2  986  450
# button_press_event: xy=(468, 282) xydata=(1343.4193548387095, 304.7112903225809) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 1343, y = 304
#       x    y
# 0   262  723
# 1   636  578
# 2   986  450
# 3  1343  304
# button_press_event: xy=(532, 304) xydata=(1565.0967741935483, 228.50967741935506) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 1565, y = 228
#       x    y
# 0   262  723
# 1   636  578
# 2   986  450
# 3  1343  304
# 4  1565  228
# button_press_event: xy=(465, 278) xydata=(1333.0282258064515, 318.56612903225835) button=3 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# remove point: index = 3
#       x    y
# 0   262  723
# 1   636  578
# 2   986  450
# 3  1565  228
# button_press_event: xy=(370, 237) xydata=(1003.9758064516129, 460.57822580645177) button=3 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# remove point: index = 2
#       x    y
# 0   262  723
# 1   636  578
# 2  1565  228
# button_press_event: xy=(272, 207) xydata=(664.5322580645161, 564.4895161290324) button=3 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# remove point: index = 1
#       x    y
# 0   262  723
# 1  1565  228
# button_press_event: xy=(145, 149) xydata=(224.64112903225805, 765.384677419355) button=3 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# remove point: index = 0
#       x    y
# 0  1565  228
# button_press_event: xy=(231, 178) xydata=(522.5201612903224, 664.9370967741937) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 522, y = 664
#       x    y
# 0   522  664
# 1  1565  228
# button_press_event: xy=(126, 134) xydata=(158.8306451612903, 817.3403225806453) button=1 dblclick=False inaxes=Axes(0.125,0.218923;0.775x0.552154)
# add point: x = 158, y = 817
#       x    y
# 0   158  817
# 1   522  664
# 2  1565  228
